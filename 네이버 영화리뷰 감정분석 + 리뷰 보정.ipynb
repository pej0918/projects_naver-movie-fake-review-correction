# %% [markdown]
# ## 리뷰 감정분석
# * 영화별 상위 500개 리뷰데이터를 테스트 데이터(예측 데이터)로 사용
# * 나머지 리뷰 데이터를 감정분석 모델링하는데 사용

# %%
import pandas as pd
import numpy as np

# %%
df_review=pd.read_csv("review_final_final.csv", encoding='cp949')
#review에 null값 제거
df_review=df_review[df_review['review'].notnull()]
df_review.head()
# Out:
#                id  rate                                             review  \
# 0    화늠(nhh5****)     5                            댓글 알바가 판을 치는군요 보면 압니다..
# 1     님(3328****)     2                    휴~ 90년대 개그와 cg…긴장감 전혀 없는 재난영화??
# 2  오이건축(jeon****)     2  두서도 없고,맥락도 없고,감동도 없고,유머만 조금,우주전쟁영화도 개연성이 있는데, ...
# 3    비즈(inab****)     5                                       기대보다 별로였어요..
# 4        xovk****     8                         승원이형 오랜만에 무도 한 편 더 찍으셨네요^^
#
#   title
# 0   싱크홀
# 1   싱크홀
# 2   싱크홀
# 3   싱크홀
# 4   싱크홀

# %%
# Group 짓기(moviename를 기준으로 묶기)
grouped = df_review.groupby("title")

# %%
df_review.groupby(['title'])['rate'].count().sort_values()
# Out:
# title
# 앵커                 962
# 디어 에반 핸슨          1004
# 스텔라               1047
# 귀문                1088
# 하우스 오브 구찌         1129
#                  ...
# 덩케르크             17549
# 스파이더맨: 노 웨이 홈    18809
# 범죄도시2            25056
# 너의 이름은.          31919
# 탑건: 매버릭          34067
# Name: rate, Length: 80, dtype: int64

# %%
#영화별로 상위 리뷰 500개씩만 추출 -> 감정분석 예측데이터로 사용할 예정
df_500reviews_per_movie=None

for i,j in grouped:
    df_m=df_review[df_review['title']==i]
    df_m=df_m.iloc[:500,:]
    df_500reviews_per_movie=pd.concat([df_500reviews_per_movie,df_m])

# %%
df_500reviews_per_movie.shape
# Out:
# (40000, 4)

# %%
#영화별로 500개씩 잘 추출이 되었는지 확인
df_500reviews_per_movie.groupby(['title'])['review'].count()
# Out:
# title
# 007 노 타임 투 다이    500
# 가을의 전설           500
# 강릉               500
# 경관의 피            500
# 고스트버스터즈 라이즈      500
#                 ...
# 해피 뉴 이어          500
# 헤어질 결심           500
# 호빗 : 뜻밖의 여정      500
# 호빗 : 스마우그의 폐허    500
# 호빗: 다섯 군대 전투     500
# Name: review, Length: 80, dtype: int64

# %%
df_500reviews_per_movie.to_csv('감정분석 테스트 데이터.csv',index=False)
df_500reviews_per_movie.head()
# Out:
#                       id  rate  \
# 75168  Fantasy(tbxo****)     9
# 75169  Debussy(kang****)     1
# 75170           milk****     7
# 75171        묵(vlue****)     2
# 75172    로저페더러(alka****)     1
#
#                                                   review          title
# 75168                                      굿바이, 다니엘 크레이그  007 노 타임 투 다이
# 75169    처음 10분은 정말 007 역대급 작품이 나오는 줄 알았다.. 근데 그게 끝이였다..  007 노 타임 투 다이
# 75170           아니 감독양반 아무리 그래도 개간지 007 형님에게 도게자가 웬말이여..  007 노 타임 투 다이
# 75171  제임스본드를 그런식으로 퇴장시켜야만 했을까?별볼일없는 등장인물들에게 촬영분량을 주어...  007 노 타임 투 다이
# 75172  크레이그 007 중 최악의 작품. 후쿠나가가 007을 쓰레기로 만들었군요. 이 작품...  007 노 타임 투 다이

# %%
ind=df_500reviews_per_movie.index
ind=ind.values.tolist()

# %%
#학습 데이터 생성(전체 데이터에서 학습데이터를 제거한 나머지 리뷰 데이터)
df_train_review=df_review.drop(ind)
df_train_review.head()
# Out:
#                        id  rate  \
# 503  zerodefect(lsh5****)     1
# 504              lbj8****     1
# 505         임성락(rakg****)     2
# 506        카스파로(casp****)    10
# 507         곽소영(cs20****)    10
#
#                                                 review title
# 503                                      7광구감독.. 말 다햇음   싱크홀
# 504  아... 영화학과 4학년생이 써도 이 시나리오 보다는 잘 쓸듯...아... 배우들의...   싱크홀
# 505  처음에는 코미디 영화인줄알았다가 조금있으니 재난영화였다가 조금있으니 슬픈영화였다가 ...   싱크홀
# 506  웃을일 하나 없는 이시국에 많이 웃고 나왔습니다. 영화는 이런 맛에 봐야 하지 싶은...   싱크홀
# 507  진짜 재미있는 포인트들이 많고 스토리도 좋고 너무 재미있었습니다 ㅠ 저는 영화 ‘ㅇ...   싱크홀

# %%
print('전체 데이터 크기 :',df_review.shape)
print('테스트 데이터 크기 :',df_500reviews_per_movie.shape)
print('학습 데이터 크기 :',df_train_review.shape)
# Out:
# 전체 데이터 크기 : (478623, 4)
# 테스트 데이터 크기 : (40000, 4)
# 학습 데이터 크기 : (438623, 4)

# %%
df_train_review.to_csv('감정분석 학습데이터.csv',index=False)

# %%
#감정분석
# 사용할 library를 먼저 모두 import
import pandas as pd
import numpy as np
import konlpy
from sklearn.feature_extraction.text import CountVectorizer   # tf-idf 방식을 사용하려면 대신 TfidfVectorizer를 import
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import re

# %%
# 텍스트를 tokenize해서 adjective, verb, noun만 추출하는 함수

def tokenize_korean_text(text): 
  text_filtered = re.sub('[^,.?!\w\s]','', text)

  okt = konlpy.tag.Okt() 
  Okt_morphs = okt.pos(text_filtered) 

  words = []
  for word, pos in Okt_morphs:
    if pos == 'Adjective' or pos == 'Verb' or pos == 'Noun':
      words.append(word)

  words_str = ' '.join(words)
  return words_str

# %%
X_texts = []
y = []

for star, comment in zip(df_train_review['rate'],df_train_review['review']):
  if 4 <= star <= 7: 
    continue  
     # 평점이 4~7인 영화는 애매하기 때문에 학습데이터로 사용하지 않음

  tokenized_comment = tokenize_korean_text(comment)  # 위에서 만들었던 함수로 comment 쪼개기
  X_texts.append(tokenized_comment)

  y.append(1 if star > 7 else -1)
    # 평점이 8 이상이면(8,9,10) 값을 1로 지정 (positive)
    # 평점이 3 이하이면(1,2,3) 값을 -1로 지정 (negative)

# %%
# train_test_split
X_train_texts, X_test_texts, y_train, y_test = train_test_split(X_texts, y, test_size=0.2, random_state=0)

# %%
# CountVectorizer로 vector화
tf_vectorizer = CountVectorizer(min_df=1, ngram_range=(1,1))
X_train_tf = tf_vectorizer.fit_transform(X_train_texts)  # training data에 맞게 fit & training data를 transform
X_test_tf = tf_vectorizer.transform(X_test_texts) # test data를 transform

vocablist = [word for word, number in sorted(tf_vectorizer.vocabulary_.items(), key=lambda x:x[1])]  # 단어들을 번호 기준 내림차순으로 저장

# %%
#학습
model = LogisticRegression(C=0.1, penalty='l2', random_state=0)
model.fit(X_train_tf, y_train)
# Out:
# c:\users\samsung\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=0.1, random_state=0)

# %%
#예측
y_test_pred = model.predict(X_test_tf)

print('Misclassified samples: {} out of {}'.format((y_test_pred != y_test).sum(), len(y_test)))
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, y_test_pred)))  # model.score(X_test_tf, y_test)로 계산해도 됨
# Out:
# Misclassified samples: 6507 out of 73999
# Accuracy: 0.91

# %%
#예측에 중요한 역할을 하는 단어들 확인
coefficients = model.coef_.tolist()

sorted_coefficients = sorted(enumerate(coefficients[0]), key=lambda x:x[1], reverse=True)
# coefficients(계수)가 큰 값부터 내림차순으로 정렬

print('긍정적인 단어 Top 10 (높은 평점과 상관관계가 강한 단어들)')
for word_num, coef in sorted_coefficients[:10]:
  print('{0:}({1:.3f})'.format(vocablist[word_num], coef))

print('\n부정적인 단어 Top 10 (낮은 평점과 상관관계가 강한 단어들)')
for word_num, coef in sorted_coefficients[-10:]: 
  print('{0:}({1:.3f})'.format(vocablist[word_num], coef))
# Out:
# 긍정적인 단어 Top 10 (높은 평점과 상관관계가 강한 단어들)
# 재밌었어요(2.621)
# 재밌었음(2.517)
# 재밌어요(2.425)
# 재밌는데(2.237)
# 존잼(2.160)
# 재미있었어요(2.075)
# 최고(2.051)
# 꿀잼(2.008)
# 좋았어요(1.963)
# 시키지(1.948)
#
# 부정적인 단어 Top 10 (낮은 평점과 상관관계가 강한 단어들)
# 쓰레기(-2.027)
# 잤다(-2.033)
# 불면증(-2.061)
# 졸작(-2.070)
# 아깝다(-2.218)
# 아까(-2.466)
# 재미없어요(-2.735)
# 노잼(-2.927)
# 재미없음(-3.007)
# 최악(-3.809)

# %%
# 긍정/부정 테스트용 함수 생성
list_result=[]
def guess_good_or_bad(text):
    text_filtered = text.replace('.', '').replace(',','').replace("'","").replace('·', ' ').replace('=','') 
    okt = konlpy.tag.Okt() 
    Okt_morphs = okt.pos(text_filtered) 
    words = []
    for word, pos in Okt_morphs:
        if pos == 'Adjective' or pos == 'Verb' or pos == 'Noun':
            words.append(word)
            
    words_str = ' '.join(words)
    new_text_tf = tf_vectorizer.transform([words_str])
    
    if model.predict(new_text_tf) == 1:
        list_result.append('긍정')
    else:
        list_result.append('부정')
    
    return list_result

# %%
df_500reviews_per_movie.head()
# Out:
#                       id  rate  \
# 75168  Fantasy(tbxo****)     9
# 75169  Debussy(kang****)     1
# 75170           milk****     7
# 75171        묵(vlue****)     2
# 75172    로저페더러(alka****)     1
#
#                                                   review          title
# 75168                                      굿바이, 다니엘 크레이그  007 노 타임 투 다이
# 75169    처음 10분은 정말 007 역대급 작품이 나오는 줄 알았다.. 근데 그게 끝이였다..  007 노 타임 투 다이
# 75170           아니 감독양반 아무리 그래도 개간지 007 형님에게 도게자가 웬말이여..  007 노 타임 투 다이
# 75171  제임스본드를 그런식으로 퇴장시켜야만 했을까?별볼일없는 등장인물들에게 촬영분량을 주어...  007 노 타임 투 다이
# 75172  크레이그 007 중 최악의 작품. 후쿠나가가 007을 쓰레기로 만들었군요. 이 작품...  007 노 타임 투 다이

# %%
#학습데이터를 제외한 나머지 데이터에 대해서 감성분석 진행
for i in range(len(df_500reviews_per_movie)):
    str_review=str(df_500reviews_per_movie.iloc[i,2])
    guess_good_or_bad(str_review)

# %%
list_result
# Out:
# ['긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '부정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '긍정',
#  '부정',
#  '긍정',
#  ...]

# %%
df_500reviews_per_movie['감성분석 결과']=list_result
df_500reviews_per_movie.head(30)
# Out:
#                                  id  rate  \
# 75168             Fantasy(tbxo****)     9
# 75169             Debussy(kang****)     1
# 75170                      milk****     7
# 75171                   묵(vlue****)     2
# 75172               로저페더러(alka****)     1
# 75173  a bittersweet life(jinc****)     9
# 75174              escuro(id44****)     7
# 75175                환웅천황(vita****)     9
# 75176            dnemdnem(bigf****)     8
# 75177                      sd68****     2
# 75178                yuri(wjdd****)     2
# 75179             낭창낭창하늘이(skyb****)     1
# 75180                  룰루(wldy****)     5
# 75181                      gang****     1
# 75182                 파슬리(hars****)     2
# 75183                 좋아여(tkon****)     1
# 75184                  소현(sohy****)     2
# 75185                   ㅇ(hiye****)     2
# 75186                      i4su****     4
# 75187                혜성혜성(soso****)     1
# 75188                햇살곰자(daek****)     6
# 75189               양과 목자(hakm****)     3
# 75190                신탱구리(moon****)     6
# 75191                  갈갈(dyb0****)     6
# 75192               sosso(min4****)     6
# 75193             Sapiens(hans****)     6
# 75194                 모미지(momi****)     2
# 75195                오틸리아(othi****)    10
# 75196               나쵸나쵸맨(club****)     6
# 75197                 송지수(ebhl****)     8
#
#                                                   review          title  \
# 75168                                      굿바이, 다니엘 크레이그  007 노 타임 투 다이
# 75169    처음 10분은 정말 007 역대급 작품이 나오는 줄 알았다.. 근데 그게 끝이였다..  007 노 타임 투 다이
# 75170           아니 감독양반 아무리 그래도 개간지 007 형님에게 도게자가 웬말이여..  007 노 타임 투 다이
# 75171  제임스본드를 그런식으로 퇴장시켜야만 했을까?별볼일없는 등장인물들에게 촬영분량을 주어...  007 노 타임 투 다이
# 75172  크레이그 007 중 최악의 작품. 후쿠나가가 007을 쓰레기로 만들었군요. 이 작품...  007 노 타임 투 다이
# 75173  난 아직도 악당들의 동기가 무엇인지 잘 모르겠다. 가족들은 왜 납치했으며 왜 화학전...  007 노 타임 투 다이
# 75174                       일본애들은 꼭 남의 음식에 와사비를 뿌린단 말이에요  007 노 타임 투 다이
# 75175  상영되고 노래나오기까지 20여분 만 봐도 아깝지 않을 정도로 강렬한 액션이 압도합니...  007 노 타임 투 다이
# 75176  크레이그의 본드를 마무리 한다는 점에서 의리로는 볼 만하지만 이전 007과는 다른 ...  007 노 타임 투 다이
# 75177  알 수 없는 전개, 석연치 않은 빌런, 천애고아의 가족애 007 / 넷플릭스 영국드...  007 노 타임 투 다이
# 75178  누구 제임스 본드가 도게자하는거 보고 싶은 사람?  감독이 영화에 일색을 묻힌건 정...  007 노 타임 투 다이
# 75179  스카이 폴에서 멈춰야 했다 진짜.... 다다미방에 도게자 일본인 이름 감독 설마했다...  007 노 타임 투 다이
# 75180  라미말렉이 다다미에 무릎꿇고 앉아있고 그 앞에 다니엘 크레이그가 미안하다며 무릎꿇고...  007 노 타임 투 다이
# 75181                                 도게자 욱일기 감독아 국뽕영화찍냐  007 노 타임 투 다이
# 75182                                   일본 감독이 다 망쳐놨음 ㅜㅜ  007 노 타임 투 다이
# 75183                               역대 최악의 엔딩. 각본 미친게 분명  007 노 타임 투 다이
# 75184                                  그냥 스카이폴에서 끝났어야했다.  007 노 타임 투 다이
# 75185               속상하다 크레이그 본드의 끝이 이래서...캐붕의 끝을 달린 영화.  007 노 타임 투 다이
# 75186  진지하게 개재미없음 러닝타임 너무 길고 억지 신파에 감독이 일본사람인지 007도게자...  007 노 타임 투 다이
# 75187                                  다니엘 크레이그가 도게자를 박네  007 노 타임 투 다이
# 75188  영상미, 마지막 다니엘크레이그의 본드는 볼만했지만 일본욱여넣기는 눈살을 찌푸리고, ...  007 노 타임 투 다이
# 75189  주관적 평가입니다 초반 10분정도는 다니엘 표 007이었는데 나머지는 가족영화로 ㅠ...  007 노 타임 투 다이
# 75190  진짜 의리로 6점 준다. 지루한 연출. 억지 신파. 어이없는 침투. 헛웃음나오는 빌...  007 노 타임 투 다이
# 75191  뜬금없는 가족애... 아버지의 사랑.... 영화보고 기억에 남은 건 오프닝곡과 팔로...  007 노 타임 투 다이
# 75192  초반은 좋았었는데... 후반부에 가족의 복수를 하는것처럼 보였던 사핀의 개연성은 갑...  007 노 타임 투 다이
# 75193     유럽식 신파, 어린 시절 상처입은 악당의  세상을 향한  복수, 반 냥 어치의 액션  007 노 타임 투 다이
# 75194  초반 액션과 팔로마 액션씬 빼고는 너무 구려요 다니엘 크레이그 007시리즈 마지막을...  007 노 타임 투 다이
# 75195  항상 마초같은 제임스가 이번엔 눈빛 만으로도 감정을 표현한 멋진 영화. 음악과 너무...  007 노 타임 투 다이
# 75196  오버하우서를 다니엘크레이그 시리즈 전체의 빌런들과 엮어서 빌런중의 빌런으로 만들어놓...  007 노 타임 투 다이
# 75197  노래나오고 30분정도까진 정말 007다운 멋진 마무리가 되겠구나 했는데.. 마지막 ...  007 노 타임 투 다이
#
#       감성분석 결과
# 75168      긍정
# 75169      긍정
# 75170      긍정
# 75171      부정
# 75172      부정
# 75173      부정
# 75174      긍정
# 75175      긍정
# 75176      긍정
# 75177      부정
# 75178      부정
# 75179      부정
# 75180      부정
# 75181      긍정
# 75182      긍정
# 75183      부정
# 75184      긍정
# 75185      긍정
# 75186      부정
# 75187      긍정
# 75188      긍정
# 75189      부정
# 75190      부정
# 75191      긍정
# 75192      부정
# 75193      긍정
# 75194      긍정
# 75195      긍정
# 75196      부정
# 75197      부정

# %%
df_500reviews_per_movie.to_csv('학습데이터(영화별 상위500개씩) 감정분석 결과.csv',index=False)

# %%
df_500reviews_per_movie.head(10)
# Out:
#                                  id  rate  \
# 75168             Fantasy(tbxo****)     9
# 75169             Debussy(kang****)     1
# 75170                      milk****     7
# 75171                   묵(vlue****)     2
# 75172               로저페더러(alka****)     1
# 75173  a bittersweet life(jinc****)     9
# 75174              escuro(id44****)     7
# 75175                환웅천황(vita****)     9
# 75176            dnemdnem(bigf****)     8
# 75177                      sd68****     2
#
#                                                   review          title  \
# 75168                                      굿바이, 다니엘 크레이그  007 노 타임 투 다이
# 75169    처음 10분은 정말 007 역대급 작품이 나오는 줄 알았다.. 근데 그게 끝이였다..  007 노 타임 투 다이
# 75170           아니 감독양반 아무리 그래도 개간지 007 형님에게 도게자가 웬말이여..  007 노 타임 투 다이
# 75171  제임스본드를 그런식으로 퇴장시켜야만 했을까?별볼일없는 등장인물들에게 촬영분량을 주어...  007 노 타임 투 다이
# 75172  크레이그 007 중 최악의 작품. 후쿠나가가 007을 쓰레기로 만들었군요. 이 작품...  007 노 타임 투 다이
# 75173  난 아직도 악당들의 동기가 무엇인지 잘 모르겠다. 가족들은 왜 납치했으며 왜 화학전...  007 노 타임 투 다이
# 75174                       일본애들은 꼭 남의 음식에 와사비를 뿌린단 말이에요  007 노 타임 투 다이
# 75175  상영되고 노래나오기까지 20여분 만 봐도 아깝지 않을 정도로 강렬한 액션이 압도합니...  007 노 타임 투 다이
# 75176  크레이그의 본드를 마무리 한다는 점에서 의리로는 볼 만하지만 이전 007과는 다른 ...  007 노 타임 투 다이
# 75177  알 수 없는 전개, 석연치 않은 빌런, 천애고아의 가족애 007 / 넷플릭스 영국드...  007 노 타임 투 다이
#
#       감성분석 결과
# 75168      긍정
# 75169      긍정
# 75170      긍정
# 75171      부정
# 75172      부정
# 75173      부정
# 75174      긍정
# 75175      긍정
# 75176      긍정
# 75177      부정

# %%
df_500reviews_per_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40000 entries, 75168 to 193294
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       40000 non-null  object
#  1   rate     40000 non-null  int64
#  2   review   40000 non-null  object
#  3   title    40000 non-null  object
#  4   감성분석 결과  40000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.8+ MB

# %%
#감정분석 결과 긍정적인데 실제 평점은 3점 이하인 댓글들(리뷰들)
df_pos=df_500reviews_per_movie[(df_500reviews_per_movie['감성분석 결과']=='긍정')&(df_500reviews_per_movie['rate']<=3)]
df_pos.to_csv('긍정인데 평점 낮은 리뷰.csv',index=False)

# %%
#감정분석 결과 부정적인데 실제 평점은 8점 이상인 댓글들(리뷰들)
df_neg=df_500reviews_per_movie[(df_500reviews_per_movie['감성분석 결과']=='부정')&(df_500reviews_per_movie['rate']>=8)]
df_neg.to_csv('부정인데 평점 높은 리뷰.csv',index=False)

# %%
df_pos
# Out:
#                        id  rate  \
# 75169   Debussy(kang****)     1
# 75181            gang****     1
# 75182       파슬리(hars****)     2
# 75184        소현(sohy****)     2
# 75185         ㅇ(hiye****)     2
# ...                   ...   ...
# 192929       치아(onen****)     1
# 192931           tndi****     1
# 192961       메아(areo****)     1
# 193090       강맹(luck****)     1
# 193092       밤달(ggus****)     1
#
#                                                    review          title  \
# 75169     처음 10분은 정말 007 역대급 작품이 나오는 줄 알았다.. 근데 그게 끝이였다..  007 노 타임 투 다이
# 75181                                  도게자 욱일기 감독아 국뽕영화찍냐  007 노 타임 투 다이
# 75182                                    일본 감독이 다 망쳐놨음 ㅜㅜ  007 노 타임 투 다이
# 75184                                   그냥 스카이폴에서 끝났어야했다.  007 노 타임 투 다이
# 75185                속상하다 크레이그 본드의 끝이 이래서...캐붕의 끝을 달린 영화.  007 노 타임 투 다이
# ...                                                   ...            ...
# 192929  1편,2편 재밌게 봤다. 그 2편도 재밌게 봤었다. 3편. 보는중에 욕이 나왔다. ...   호빗: 다섯 군대 전투
# 192931                     예고편서 나오는 엘프활부대 활쏘는장면 어따 팔아먹었음?   호빗: 다섯 군대 전투
# 192961                 평점 조절용. 반지의 제왕 모든 시리즈 중 가장 못만든 영화.   호빗: 다섯 군대 전투
# 193090            맨칼쌈짓거리 돈이 아깝네 이런건집에서 봐야하는 영화 고만 울궈라이늠들아   호빗: 다섯 군대 전투
# 193092  평점이너무높게형성되있는것같아 글올립니다 . 저는오늘 조조로 보고왔는데 진짜 재미없게...   호빗: 다섯 군대 전투
#
#        감성분석 결과
# 75169       긍정
# 75181       긍정
# 75182       긍정
# 75184       긍정
# 75185       긍정
# ...        ...
# 192929      긍정
# 192931      긍정
# 192961      긍정
# 193090      긍정
# 193092      긍정
#
# [3109 rows x 5 columns]

# %%
df_neg
# Out:
#                                   id  rate  \
# 75173   a bittersweet life(jinc****)     9
# 75197                  송지수(ebhl****)     8
# 75339                  하루키(mkha****)     8
# 75380                 햇살처럼(guru****)     8
# 75476                   치즈(chzt****)     8
# ...                              ...   ...
# 193084                      wndo****     8
# 193144                대한건아(dhdl****)    10
# 193162                이라이자(funk****)    10
# 193206                      jaha****    10
# 193219                      w740****     9
#
#                                                    review          title  \
# 75173   난 아직도 악당들의 동기가 무엇인지 잘 모르겠다. 가족들은 왜 납치했으며 왜 화학전...  007 노 타임 투 다이
# 75197   노래나오고 30분정도까진 정말 007다운 멋진 마무리가 되겠구나 했는데.. 마지막 ...  007 노 타임 투 다이
# 75339   007을 이런 식으로 보낸다는 게 참...내용도 그닥 와닿지도 않고, 부성애는 공감...  007 노 타임 투 다이
# 75380   음 다니엘의 007 마지막편이었는데 일본 감독?이라서 그런지 왜색도 짖고 조금 실망...  007 노 타임 투 다이
# 75476                                     기대한 것 보다는 별로였어요  007 노 타임 투 다이
# ...                                                   ...            ...
# 193084                                    기대한만큼은 그닥 아닌듯 ㅎ   호빗: 다섯 군대 전투
# 193144  후... 확장판봤는데 이거 너무 심하게 편집된거 아닌지 모르겠네요/// 너무하네 진...   호빗: 다섯 군대 전투
# 193162  중간부터 한참을 대사없는 전쟁신이었는데도 지루함을 못 느꼈다. 생일날 보았는데, 정...   호빗: 다섯 군대 전투
# 193206          급전개랑 전략적인 요소가 없는 개판 싸움만 빼면ㅋㅋㅋㅋ 볼만합니다 CG굿!   호빗: 다섯 군대 전투
# 193219           영화 내용 모르면 그냥 보러 오지 마세요 뭔 내용인지 모르겠다고 하지말공   호빗: 다섯 군대 전투
#
#        감성분석 결과
# 75173       부정
# 75197       부정
# 75339       부정
# 75380       부정
# 75476       부정
# ...        ...
# 193084      부정
# 193144      부정
# 193162      부정
# 193206      부정
# 193219      부정
#
# [404 rows x 5 columns]

# %% [markdown]
# ## 가짜 리뷰 제거

# %%
pos_index=df_pos.index.tolist()
neg_index=df_neg.index.tolist()

# %%
df_review.to_csv('review_final_nonnull.csv',index=True)

# %%
#이상리뷰 인덱스
index_review=pos_index+neg_index
index_review
# Out:
# [75169,
#  75181,
#  75182,
#  75184,
#  75185,
#  75187,
#  75194,
#  75200,
#  75212,
#  75251,
#  75265,
#  75277,
#  75290,
#  75299,
#  75313,
#  75323,
#  75331,
#  75347,
#  75349,
#  75367,
#  75402,
#  75423,
#  75438,
#  75440,
#  75450,
#  75456,
#  75538,
#  75547,
#  75557,
#  75559,
#  75561,
#  75590,
#  75594,
#  75597,
#  75599,
#  75629,
#  75659,
#  75661,
#  75668,
#  104556,
#  104557,
#  104582,
#  104596,
#  104597,
#  104602,
#  104607,
#  104628,
#  104645,
#  104653,
#  104657,
#  104675,
#  104694,
#  104754,
#  104766,
#  104767,
#  104768,
#  104784,
#  104821,
#  104872,
#  104874,
#  104878,
#  104880,
#  104881,
#  104883,
#  104884,
#  136872,
#  136878,
#  136879,
#  136880,
#  136881,
#  136883,
#  136884,
#  136886,
#  136887,
#  136894,
#  136914,
#  136923,
#  136926,
#  136945,
#  136957,
#  136983,
#  137005,
#  137031,
#  137043,
#  137047,
#  137050,
#  137057,
#  137058,
#  137059,
#  137102,
#  137104,
#  137108,
#  137109,
#  137123,
#  137127,
#  137132,
#  137134,
#  137136,
#  137137,
#  137141,
#  137145,
#  137149,
#  137155,
#  137156,
#  137159,
#  137161,
#  137162,
#  137212,
#  137222,
#  137225,
#  137230,
#  137234,
#  137236,
#  137239,
#  137241,
#  137248,
#  137251,
#  137254,
#  137255,
#  137256,
#  137258,
#  137260,
#  137263,
#  137267,
#  137275,
#  137277,
#  137278,
#  137279,
#  137281,
#  137328,
#  137329,
#  137333,
#  137335,
#  137336,
#  137340,
#  137341,
#  137342,
#  137343,
#  137344,
#  137347,
#  137348,
#  137350,
#  137351,
#  137352,
#  137357,
#  137362,
#  137364,
#  137369,
#  137370,
#  137372,
#  137373,
#  231450,
#  231458,
#  231492,
#  231515,
#  231586,
#  231598,
#  231605,
#  231648,
#  231653,
#  231654,
#  231689,
#  231712,
#  231713,
#  231772,
#  231829,
#  231847,
#  231877,
#  231879,
#  231882,
#  231883,
#  231889,
#  231903,
#  214747,
#  214765,
#  214770,
#  214771,
#  214780,
#  214920,
#  214924,
#  214933,
#  214976,
#  215005,
#  215022,
#  215059,
#  215091,
#  157543,
#  157544,
#  157545,
#  157546,
#  157548,
#  157552,
#  157553,
#  157555,
#  157556,
#  157557,
#  157558,
#  157560,
#  157563,
#  157564,
#  157565,
#  157569,
#  157571,
#  157572,
#  157573,
#  157575,
#  157576,
#  157577,
#  157578,
#  157580,
#  157581,
#  157582,
#  157583,
#  157584,
#  157589,
#  157661,
#  157663,
#  157665,
#  157671,
#  157674,
#  157675,
#  157691,
#  157692,
#  157694,
#  157696,
#  157698,
#  157702,
#  157705,
#  157708,
#  157710,
#  157738,
#  157740,
#  157756,
#  157759,
#  157760,
#  157769,
#  157771,
#  157772,
#  157788,
#  157790,
#  157791,
#  157792,
#  157808,
#  157809,
#  157814,
#  157819,
#  157820,
#  157822,
#  157825,
#  157827,
#  157828,
#  157830,
#  157837,
#  157856,
#  157858,
#  157863,
#  157864,
#  157866,
#  157867,
#  157868,
#  157869,
#  157870,
#  157872,
#  157873,
#  157876,
#  157883,
#  157897,
#  157900,
#  157912,
#  157916,
#  157917,
#  157920,
#  157923,
#  157924,
#  157925,
#  157927,
#  157928,
#  157930,
#  157932,
#  157933,
#  157934,
#  157935,
#  157936,
#  157937,
#  157939,
#  157941,
#  157954,
#  157959,
#  157965,
#  157982,
#  157985,
#  157986,
#  157987,
#  157990,
#  157991,
#  158000,
#  158003,
#  158004,
#  158013,
#  158021,
#  158022,
#  158023,
#  158024,
#  158025,
#  158026,
#  158027,
#  158028,
#  158029,
#  158030,
#  158031,
#  158033,
#  158034,
#  158036,
#  158037,
#  158038,
#  158039,
#  158040,
#  158047,
#  158048,
#  158049,
#  158050,
#  158058,
#  158065,
#  158066,
#  158076,
#  107025,
#  107127,
#  107153,
#  107325,
#  282029,
#  282131,
#  282153,
#  282171,
#  282173,
#  282258,
#  282315,
#  282351,
#  26156,
#  26158,
#  26161,
#  26165,
#  26167,
#  26169,
#  26170,
#  26172,
#  26173,
#  26174,
#  26177,
#  26179,
#  26182,
#  26184,
#  26191,
#  26198,
#  26209,
#  26211,
#  26212,
#  26213,
#  26217,
#  26238,
#  26239,
#  26240,
#  26245,
#  26247,
#  26251,
#  26254,
#  26256,
#  26265,
#  26274,
#  26283,
#  26286,
#  26287,
#  26290,
#  26291,
#  26297,
#  26300,
#  26301,
#  26305,
#  26310,
#  26312,
#  26322,
#  26344,
#  26346,
#  26348,
#  26353,
#  26354,
#  26356,
#  26359,
#  26362,
#  26363,
#  26365,
#  26366,
#  26396,
#  26446,
#  26447,
#  26474,
#  26481,
#  26484,
#  26485,
#  26487,
#  26489,
#  26491,
#  26505,
#  26513,
#  26517,
#  26524,
#  26525,
#  26526,
#  26535,
#  26536,
#  26538,
#  26545,
#  26546,
#  26551,
#  26555,
#  26560,
#  26566,
#  26567,
#  26570,
#  26581,
#  26585,
#  26587,
#  26591,
#  26593,
#  26604,
#  26609,
#  26614,
#  26616,
#  26619,
#  26622,
#  26624,
#  26632,
#  26638,
#  26641,
#  26650,
#  26653,
#  26657,
#  26660,
#  26661,
#  26665,
#  26670,
#  354855,
#  355292,
#  355303,
#  87358,
#  87359,
#  87360,
#  87362,
#  87364,
#  87366,
#  87367,
#  87369,
#  87375,
#  87377,
#  87378,
#  87381,
#  87383,
#  87390,
#  87391,
#  87394,
#  87395,
#  87397,
#  87398,
#  87409,
#  87411,
#  87412,
#  87413,
#  87414,
#  87417,
#  87421,
#  87422,
#  87424,
#  87430,
#  87434,
#  87437,
#  87445,
#  87447,
#  87448,
#  87480,
#  87524,
#  87525,
#  87527,
#  87551,
#  87555,
#  87599,
#  87600,
#  87603,
#  87610,
#  87613,
#  87614,
#  87615,
#  87617,
#  87618,
#  87653,
#  87666,
#  87678,
#  87679,
#  87682,
#  87684,
#  87686,
#  87689,
#  87691,
#  87694,
#  87695,
#  87697,
#  87698,
#  87700,
#  87701,
#  87703,
#  87706,
#  87709,
#  87710,
#  87713,
#  498225,
#  498295,
#  498383,
#  498404,
#  498406,
#  283225,
#  283228,
#  283233,
#  283238,
#  283240,
#  283241,
#  283243,
#  283248,
#  283249,
#  283250,
#  283251,
#  283252,
#  283254,
#  283257,
#  283258,
#  283261,
#  283264,
#  283265,
#  283267,
#  283273,
#  283275,
#  283276,
#  283277,
#  283278,
#  283283,
#  283290,
#  283295,
#  283296,
#  283297,
#  283298,
#  283299,
#  283301,
#  283302,
#  283304,
#  283305,
#  283306,
#  283310,
#  283311,
#  283314,
#  283315,
#  283318,
#  283320,
#  283323,
#  283324,
#  283330,
#  283333,
#  283335,
#  283342,
#  283343,
#  283344,
#  283349,
#  283350,
#  283352,
#  283355,
#  283356,
#  283357,
#  283358,
#  283364,
#  283367,
#  283371,
#  283372,
#  283373,
#  283376,
#  283378,
#  283380,
#  283381,
#  283383,
#  283387,
#  283388,
#  283389,
#  283391,
#  283392,
#  283395,
#  283396,
#  283398,
#  283399,
#  283400,
#  283403,
#  283404,
#  283406,
#  283408,
#  283410,
#  283418,
#  283420,
#  283421,
#  283426,
#  283427,
#  283428,
#  283429,
#  283430,
#  283431,
#  283433,
#  283434,
#  283437,
#  283439,
#  283441,
#  283442,
#  283457,
#  283459,
#  283462,
#  283464,
#  283465,
#  283467,
#  283473,
#  283478,
#  283479,
#  283480,
#  283499,
#  283502,
#  283503,
#  283509,
#  283511,
#  283513,
#  283515,
#  283518,
#  283524,
#  283527,
#  283544,
#  283548,
#  283552,
#  283553,
#  283554,
#  283564,
#  283566,
#  283567,
#  283569,
#  283570,
#  283571,
#  283599,
#  283601,
#  283602,
#  283604,
#  283612,
#  283613,
#  283615,
#  283620,
#  283629,
#  283637,
#  283638,
#  283640,
#  283644,
#  283655,
#  283669,
#  283673,
#  283698,
#  283703,
#  283704,
#  283714,
#  283716,
#  278931,
#  279009,
#  279056,
#  279077,
#  279090,
#  279094,
#  279134,
#  279145,
#  279149,
#  279198,
#  279303,
#  279309,
#  279348,
#  279413,
#  279414,
#  279422,
#  279423,
#  279429,
#  68923,
#  68943,
#  68983,
#  69013,
#  69014,
#  69024,
#  69134,
#  69148,
#  69194,
#  69229,
#  69232,
#  69234,
#  69295,
#  69297,
#  69301,
#  69305,
#  69307,
#  69315,
#  69319,
#  69320,
#  69342,
#  69352,
#  69401,
#  69402,
#  27328,
#  27341,
#  27344,
#  27347,
#  27356,
#  27361,
#  27362,
#  27363,
#  27367,
#  27370,
#  27381,
#  27385,
#  27386,
#  27387,
#  27389,
#  27391,
#  27397,
#  27400,
#  27401,
#  27402,
#  27408,
#  27409,
#  27411,
#  27416,
#  27420,
#  27432,
#  27434,
#  27436,
#  27437,
#  27438,
#  27439,
#  27449,
#  27451,
#  27452,
#  27456,
#  27458,
#  27463,
#  27465,
#  27466,
#  27471,
#  27473,
#  27475,
#  27480,
#  27481,
#  27484,
#  27485,
#  27489,
#  27494,
#  27495,
#  27497,
#  27499,
#  27501,
#  27502,
#  27503,
#  27504,
#  27505,
#  27509,
#  27510,
#  27511,
#  27513,
#  27515,
#  27518,
#  27524,
#  27525,
#  27526,
#  27527,
#  27532,
#  27536,
#  27538,
#  27544,
#  27546,
#  27549,
#  27550,
#  27551,
#  27553,
#  27560,
#  27561,
#  27565,
#  27566,
#  27568,
#  27576,
#  27589,
#  27594,
#  27602,
#  27603,
#  27609,
#  27611,
#  27613,
#  27615,
#  27620,
#  27633,
#  27639,
#  27640,
#  27644,
#  27647,
#  27651,
#  27652,
#  27653,
#  27654,
#  27658,
#  27662,
#  27663,
#  27677,
#  27678,
#  27680,
#  27681,
#  27682,
#  27683,
#  27687,
#  27688,
#  27689,
#  27694,
#  27697,
#  27698,
#  27699,
#  27701,
#  27703,
#  27706,
#  27707,
#  27710,
#  27713,
#  27718,
#  27720,
#  27724,
#  27725,
#  27728,
#  27729,
#  27730,
#  27734,
#  27736,
#  27737,
#  27745,
#  27760,
#  27762,
#  309748,
#  309908,
#  309909,
#  309932,
#  309949,
#  309952,
#  309958,
#  309970,
#  309994,
#  310038,
#  310053,
#  310054,
#  310061,
#  310066,
#  310067,
#  310070,
#  310096,
#  310101,
#  310113,
#  338113,
#  338120,
#  338126,
#  338133,
#  338134,
#  338162,
#  338177,
#  338200,
#  338203,
#  338235,
#  338244,
#  338260,
#  338298,
#  338300,
#  338301,
#  338331,
#  338332,
#  338416,
#  338442,
#  338468,
#  338515,
#  338546,
#  338570,
#  284520,
#  284539,
#  284540,
#  284630,
#  284694,
#  284726,
#  284783,
#  284792,
#  284870,
#  284877,
#  284887,
#  284888,
#  284898,
#  284953,
#  284955,
#  284959,
#  284962,
#  284963,
#  284965,
#  284968,
#  284975,
#  284976,
#  284980,
#  284982,
#  284986,
#  284987,
#  284990,
#  284992,
#  284994,
#  20858,
#  20906,
#  20929,
#  20953,
#  20975,
#  20979,
#  20997,
#  21015,
#  21019,
#  21027,
#  21034,
#  21036,
#  21041,
#  21042,
#  21043,
#  21044,
#  21109,
#  21154,
#  21162,
#  21167,
#  21168,
#  21189,
#  21196,
#  21201,
#  21203,
#  21210,
#  21268,
#  21297,
#  21309,
#  21314,
#  21319,
#  21321,
#  21325,
#  499353,
#  499499,
#  499550,
#  499572,
#  499573,
#  499574,
#  499577,
#  499579,
#  499618,
#  499673,
#  499676,
#  499677,
#  499756,
#  499759,
#  499760,
#  499767,
#  499769,
#  499782,
#  499783,
#  499793,
#  499817,
#  499819,
#  499820,
#  499824,
#  499825,
#  499832,
#  499844,
#  240352,
#  240358,
#  240360,
#  240363,
#  240364,
#  240368,
#  240369,
#  240372,
#  240373,
#  240377,
#  240378,
#  240379,
#  240380,
#  240381,
#  240383,
#  240385,
#  240387,
#  240391,
#  240393,
#  240394,
#  240397,
#  240398,
#  240399,
#  240401,
#  240405,
#  240408,
#  240411,
#  ...]

# %%
#학습 데이터 인덱스도 리뷰 보정할 때 빼야함
df_train_review.head()
# Out:
#                        id  rate  \
# 503  zerodefect(lsh5****)     1
# 504              lbj8****     1
# 505         임성락(rakg****)     2
# 506        카스파로(casp****)    10
# 507         곽소영(cs20****)    10
#
#                                                 review title
# 503                                      7광구감독.. 말 다햇음   싱크홀
# 504  아... 영화학과 4학년생이 써도 이 시나리오 보다는 잘 쓸듯...아... 배우들의...   싱크홀
# 505  처음에는 코미디 영화인줄알았다가 조금있으니 재난영화였다가 조금있으니 슬픈영화였다가 ...   싱크홀
# 506  웃을일 하나 없는 이시국에 많이 웃고 나왔습니다. 영화는 이런 맛에 봐야 하지 싶은...   싱크홀
# 507  진짜 재미있는 포인트들이 많고 스토리도 좋고 너무 재미있었습니다 ㅠ 저는 영화 ‘ㅇ...   싱크홀

# %%
list_df_train_review=df_train_review.index.tolist()

# %%
#Null값이 있는 인덱스도 제거해줘야 함
df_review_=pd.read_csv("review_final_final.csv", encoding='cp949')
df_review_null=df_review_[df_review_['review'].isnull()]

# %%
df_review_null.head()
# Out:
#                          id  rate review title
# 225          Deby(78_h****)     4    NaN   싱크홀
# 253         6uoas(seon****)    10    NaN   싱크홀
# 277                alsw****    10    NaN   싱크홀
# 510           스파이(wldu****)     4    NaN   싱크홀
# 517  Yes babyyyyy(jung****)     1    NaN   싱크홀

# %%
null_list=df_review_null.index.tolist()

# %%
null_list
# Out:
# [225,
#  253,
#  277,
#  510,
#  517,
#  551,
#  555,
#  559,
#  658,
#  728,
#  746,
#  817,
#  889,
#  897,
#  900,
#  998,
#  1015,
#  1123,
#  1137,
#  1139,
#  1224,
#  1389,
#  1435,
#  1461,
#  1492,
#  1496,
#  1530,
#  1553,
#  1576,
#  1626,
#  1650,
#  1675,
#  1676,
#  1694,
#  1696,
#  1700,
#  1747,
#  1759,
#  1760,
#  1763,
#  1775,
#  1879,
#  1910,
#  1928,
#  1984,
#  2012,
#  2074,
#  2171,
#  2180,
#  2189,
#  2197,
#  2201,
#  2357,
#  2411,
#  2455,
#  2500,
#  2543,
#  2553,
#  2588,
#  2629,
#  2632,
#  2642,
#  2656,
#  2668,
#  2694,
#  2712,
#  2726,
#  2730,
#  2734,
#  2743,
#  2745,
#  2750,
#  2789,
#  2793,
#  2811,
#  2824,
#  2826,
#  2832,
#  2848,
#  2863,
#  2886,
#  2904,
#  2924,
#  2978,
#  2994,
#  3002,
#  3038,
#  3045,
#  3085,
#  3088,
#  3202,
#  3217,
#  3231,
#  3241,
#  3294,
#  3318,
#  3327,
#  3335,
#  3343,
#  3350,
#  3360,
#  3375,
#  3477,
#  3527,
#  3547,
#  3548,
#  3565,
#  3632,
#  3645,
#  3646,
#  3649,
#  3669,
#  3679,
#  3692,
#  3755,
#  3785,
#  3791,
#  3792,
#  3847,
#  3862,
#  3865,
#  3972,
#  3974,
#  3977,
#  4011,
#  4027,
#  4036,
#  4227,
#  4294,
#  4349,
#  4384,
#  4413,
#  4546,
#  4551,
#  4577,
#  4626,
#  4673,
#  4683,
#  4802,
#  4805,
#  4808,
#  4821,
#  4843,
#  4863,
#  4866,
#  4867,
#  4908,
#  4934,
#  4965,
#  4997,
#  5000,
#  5025,
#  5114,
#  5131,
#  5136,
#  5144,
#  5153,
#  5197,
#  5202,
#  5287,
#  5328,
#  5334,
#  5387,
#  5413,
#  5417,
#  5433,
#  5476,
#  5489,
#  5500,
#  5515,
#  5536,
#  5543,
#  5546,
#  5567,
#  5569,
#  5587,
#  5594,
#  5636,
#  5685,
#  5688,
#  5738,
#  5747,
#  5749,
#  5766,
#  5778,
#  5843,
#  5864,
#  5870,
#  5871,
#  5876,
#  5880,
#  5897,
#  5925,
#  6001,
#  6048,
#  6058,
#  6059,
#  6065,
#  6072,
#  6093,
#  6157,
#  6165,
#  6183,
#  6195,
#  6232,
#  6241,
#  6269,
#  6358,
#  6359,
#  6533,
#  6606,
#  6616,
#  6651,
#  6730,
#  6820,
#  6826,
#  6853,
#  6860,
#  6870,
#  6916,
#  6930,
#  7004,
#  7061,
#  7074,
#  7080,
#  7092,
#  7116,
#  7160,
#  7169,
#  7224,
#  7263,
#  7301,
#  7323,
#  7433,
#  7437,
#  7454,
#  7518,
#  7539,
#  7587,
#  7593,
#  7596,
#  7603,
#  7608,
#  7648,
#  7662,
#  7669,
#  7670,
#  7671,
#  7675,
#  7677,
#  7699,
#  7700,
#  7730,
#  7737,
#  7749,
#  7760,
#  7768,
#  7773,
#  7786,
#  7787,
#  7798,
#  7802,
#  7809,
#  7830,
#  7835,
#  7853,
#  7859,
#  7863,
#  7867,
#  7879,
#  7911,
#  7970,
#  8023,
#  8044,
#  8048,
#  8069,
#  8078,
#  8080,
#  8081,
#  8084,
#  8087,
#  8094,
#  8098,
#  8099,
#  8101,
#  8102,
#  8103,
#  8124,
#  8141,
#  8150,
#  8161,
#  8169,
#  8180,
#  8194,
#  8200,
#  8207,
#  8213,
#  8217,
#  8226,
#  8249,
#  8280,
#  8308,
#  8325,
#  8349,
#  8384,
#  8446,
#  8467,
#  8521,
#  8550,
#  8596,
#  8607,
#  8609,
#  8643,
#  8647,
#  8661,
#  8668,
#  8672,
#  8676,
#  8682,
#  8683,
#  8733,
#  8736,
#  8737,
#  8740,
#  8752,
#  8756,
#  8762,
#  8776,
#  8796,
#  8822,
#  8843,
#  8853,
#  8882,
#  8969,
#  8970,
#  8971,
#  8989,
#  8994,
#  9049,
#  9053,
#  9054,
#  9055,
#  9057,
#  9082,
#  9112,
#  9113,
#  9118,
#  9126,
#  9172,
#  9184,
#  9218,
#  9237,
#  9528,
#  9642,
#  9696,
#  9697,
#  9925,
#  9939,
#  9964,
#  9965,
#  10078,
#  10165,
#  10215,
#  10286,
#  10290,
#  10361,
#  10365,
#  10515,
#  10601,
#  10643,
#  10745,
#  10758,
#  10799,
#  10820,
#  10856,
#  10923,
#  10985,
#  10995,
#  11045,
#  11054,
#  11156,
#  11160,
#  11174,
#  11208,
#  11317,
#  11361,
#  11421,
#  11482,
#  11512,
#  11527,
#  11560,
#  11581,
#  11587,
#  11737,
#  11756,
#  11772,
#  11777,
#  11804,
#  11849,
#  11906,
#  11908,
#  11917,
#  11991,
#  12084,
#  12243,
#  12256,
#  12333,
#  12352,
#  12377,
#  12414,
#  12415,
#  12429,
#  12454,
#  12471,
#  12476,
#  12477,
#  12485,
#  12523,
#  12548,
#  12557,
#  12565,
#  12569,
#  12580,
#  12602,
#  12606,
#  12617,
#  12649,
#  12664,
#  12718,
#  12757,
#  12768,
#  12769,
#  12789,
#  12796,
#  12830,
#  12831,
#  12860,
#  12863,
#  12866,
#  12901,
#  12903,
#  12904,
#  12975,
#  12976,
#  12978,
#  12990,
#  12994,
#  13004,
#  13006,
#  13014,
#  13041,
#  13043,
#  13076,
#  13080,
#  13083,
#  13090,
#  13096,
#  13100,
#  13102,
#  13121,
#  13221,
#  13229,
#  13239,
#  13267,
#  13288,
#  13327,
#  13351,
#  13396,
#  13402,
#  13413,
#  13457,
#  13489,
#  13509,
#  13516,
#  13536,
#  13662,
#  13679,
#  13748,
#  13789,
#  13836,
#  13869,
#  13926,
#  13932,
#  13941,
#  13944,
#  13946,
#  14040,
#  14043,
#  14073,
#  14075,
#  14079,
#  14095,
#  14098,
#  14099,
#  14102,
#  14105,
#  14136,
#  14162,
#  14205,
#  14209,
#  14224,
#  14250,
#  14256,
#  14293,
#  14300,
#  14307,
#  14312,
#  14327,
#  14330,
#  14337,
#  14338,
#  14339,
#  14352,
#  14374,
#  14408,
#  14414,
#  14447,
#  14459,
#  14471,
#  14479,
#  14493,
#  14495,
#  14520,
#  14524,
#  14550,
#  14562,
#  14569,
#  14577,
#  14578,
#  14602,
#  14627,
#  14663,
#  14690,
#  14735,
#  14736,
#  14739,
#  14799,
#  14841,
#  14912,
#  14987,
#  15011,
#  15012,
#  15052,
#  15103,
#  15105,
#  15117,
#  15125,
#  15144,
#  15390,
#  15391,
#  15392,
#  15394,
#  15395,
#  18478,
#  18504,
#  18539,
#  18571,
#  18602,
#  18605,
#  18607,
#  18619,
#  18630,
#  18682,
#  18693,
#  18724,
#  18727,
#  18729,
#  18732,
#  18784,
#  18802,
#  18811,
#  18873,
#  18953,
#  18977,
#  19002,
#  19020,
#  19049,
#  19052,
#  19070,
#  19076,
#  19078,
#  19100,
#  19114,
#  19121,
#  19156,
#  19167,
#  19168,
#  19169,
#  19186,
#  19195,
#  19197,
#  19285,
#  19286,
#  19293,
#  19301,
#  19307,
#  19308,
#  19335,
#  19345,
#  19353,
#  19394,
#  19395,
#  19396,
#  19445,
#  19453,
#  19478,
#  19509,
#  19554,
#  19587,
#  19601,
#  19612,
#  19626,
#  19705,
#  19714,
#  19719,
#  19756,
#  19766,
#  19792,
#  19823,
#  19825,
#  19839,
#  19845,
#  19893,
#  19905,
#  19906,
#  19910,
#  19912,
#  20003,
#  20024,
#  20027,
#  20064,
#  20103,
#  20125,
#  20188,
#  20224,
#  20255,
#  20386,
#  20416,
#  20418,
#  20528,
#  20529,
#  20552,
#  20563,
#  20608,
#  20684,
#  20699,
#  21225,
#  21234,
#  21258,
#  21292,
#  21301,
#  21305,
#  21337,
#  21342,
#  21367,
#  21382,
#  21399,
#  21404,
#  21439,
#  21450,
#  21465,
#  21472,
#  21529,
#  21548,
#  21561,
#  21566,
#  21578,
#  21623,
#  21632,
#  21649,
#  21657,
#  21673,
#  21689,
#  21692,
#  21715,
#  21720,
#  21746,
#  21750,
#  21811,
#  21836,
#  21868,
#  22056,
#  22069,
#  22082,
#  22092,
#  22172,
#  22204,
#  22206,
#  22219,
#  22238,
#  22244,
#  22312,
#  22391,
#  22397,
#  22428,
#  22506,
#  22625,
#  22673,
#  22741,
#  22791,
#  22808,
#  22819,
#  22875,
#  22981,
#  22983,
#  23017,
#  23090,
#  23095,
#  23221,
#  23292,
#  23487,
#  23494,
#  23570,
#  23702,
#  23705,
#  23782,
#  23797,
#  23805,
#  23809,
#  23812,
#  23824,
#  23833,
#  23873,
#  23905,
#  23923,
#  23962,
#  24021,
#  24037,
#  24060,
#  24116,
#  24271,
#  24313,
#  24361,
#  24395,
#  24401,
#  24449,
#  24457,
#  24492,
#  24498,
#  24545,
#  24638,
#  24693,
#  24924,
#  24973,
#  25042,
#  25050,
#  25881,
#  25882,
#  26227,
#  26388,
#  26439,
#  26453,
#  26454,
#  26467,
#  26476,
#  26488,
#  26503,
#  26553,
#  26578,
#  26589,
#  26606,
#  26627,
#  26651,
#  26664,
#  26703,
#  26711,
#  26794,
#  26871,
#  27252,
#  29025,
#  30268,
#  30274,
#  30276,
#  30278,
#  30280,
#  30281,
#  30294,
#  30299,
#  30301,
#  30302,
#  30303,
#  30311,
#  30320,
#  34159,
#  34161,
#  34407,
#  34421,
#  34472,
#  34475,
#  34478,
#  34480,
#  34481,
#  34494,
#  34496,
#  34583,
#  34585,
#  34591,
#  34598,
#  34605,
#  34607,
#  34612,
#  34622,
#  34624,
#  34626,
#  34630,
#  34650,
#  34652,
#  34655,
#  34656,
#  34659,
#  34662,
#  34664,
#  34669,
#  34682,
#  34683,
#  34688,
#  34690,
#  34694,
#  34696,
#  34699,
#  34707,
#  34715,
#  34716,
#  34720,
#  34729,
#  34734,
#  34735,
#  34736,
#  34738,
#  34741,
#  34751,
#  34754,
#  34757,
#  34758,
#  34761,
#  34771,
#  34786,
#  36103,
#  40529,
#  42305,
#  42793,
#  42800,
#  42816,
#  42824,
#  42825,
#  42844,
#  42851,
#  42857,
#  42867,
#  42868,
#  42878,
#  42883,
#  42884,
#  42885,
#  42889,
#  42907,
#  42912,
#  42913,
#  42916,
#  42927,
#  42948,
#  42974,
#  42980,
#  42981,
#  42988,
#  43000,
#  43010,
#  43029,
#  43032,
#  43053,
#  43056,
#  43074,
#  43078,
#  43083,
#  43117,
#  43132,
#  43146,
#  43153,
#  43154,
#  43161,
#  43172,
#  43195,
#  43198,
#  43236,
#  43238,
#  43244,
#  43252,
#  43268,
#  43279,
#  43281,
#  43282,
#  43283,
#  43299,
#  43301,
#  43307,
#  43309,
#  43315,
#  43318,
#  43330,
#  43337,
#  43347,
#  43362,
#  43363,
#  43364,
#  43365,
#  43368,
#  43396,
#  43402,
#  43405,
#  43419,
#  43429,
#  43434,
#  43445,
#  43468,
#  43471,
#  43480,
#  43482,
#  43486,
#  43487,
#  43489,
#  43498,
#  43502,
#  43503,
#  43504,
#  43517,
#  43519,
#  43522,
#  43530,
#  43532,
#  43533,
#  43537,
#  43539,
#  43544,
#  43546,
#  43547,
#  43548,
#  43549,
#  43550,
#  43551,
#  43552,
#  43555,
#  43558,
#  43562,
#  43563,
#  43565,
#  43569,
#  43582,
#  43583,
#  43588,
#  43589,
#  43600,
#  43606,
#  43613,
#  43616,
#  43617,
#  43620,
#  43621,
#  43628,
#  43630,
#  43639,
#  43640,
#  43641,
#  43642,
#  43643,
#  43644,
#  43646,
#  43647,
#  43649,
#  43650,
#  43654,
#  43655,
#  43656,
#  43660,
#  43661,
#  43663,
#  43664,
#  43665,
#  43667,
#  43670,
#  43671,
#  43674,
#  43678,
#  43686,
#  43687,
#  43688,
#  43689,
#  43690,
#  43691,
#  43692,
#  43694,
#  43698,
#  43700,
#  43702,
#  43706,
#  43710,
#  43712,
#  43715,
#  43716,
#  43732,
#  43735,
#  ...]

# %%
list_drop_index= pos_index + neg_index + list_df_train_review
list_drop_index
# Out:
# [75169,
#  75181,
#  75182,
#  75184,
#  75185,
#  75187,
#  75194,
#  75200,
#  75212,
#  75251,
#  75265,
#  75277,
#  75290,
#  75299,
#  75313,
#  75323,
#  75331,
#  75347,
#  75349,
#  75367,
#  75402,
#  75423,
#  75438,
#  75440,
#  75450,
#  75456,
#  75538,
#  75547,
#  75557,
#  75559,
#  75561,
#  75590,
#  75594,
#  75597,
#  75599,
#  75629,
#  75659,
#  75661,
#  75668,
#  104556,
#  104557,
#  104582,
#  104596,
#  104597,
#  104602,
#  104607,
#  104628,
#  104645,
#  104653,
#  104657,
#  104675,
#  104694,
#  104754,
#  104766,
#  104767,
#  104768,
#  104784,
#  104821,
#  104872,
#  104874,
#  104878,
#  104880,
#  104881,
#  104883,
#  104884,
#  136872,
#  136878,
#  136879,
#  136880,
#  136881,
#  136883,
#  136884,
#  136886,
#  136887,
#  136894,
#  136914,
#  136923,
#  136926,
#  136945,
#  136957,
#  136983,
#  137005,
#  137031,
#  137043,
#  137047,
#  137050,
#  137057,
#  137058,
#  137059,
#  137102,
#  137104,
#  137108,
#  137109,
#  137123,
#  137127,
#  137132,
#  137134,
#  137136,
#  137137,
#  137141,
#  137145,
#  137149,
#  137155,
#  137156,
#  137159,
#  137161,
#  137162,
#  137212,
#  137222,
#  137225,
#  137230,
#  137234,
#  137236,
#  137239,
#  137241,
#  137248,
#  137251,
#  137254,
#  137255,
#  137256,
#  137258,
#  137260,
#  137263,
#  137267,
#  137275,
#  137277,
#  137278,
#  137279,
#  137281,
#  137328,
#  137329,
#  137333,
#  137335,
#  137336,
#  137340,
#  137341,
#  137342,
#  137343,
#  137344,
#  137347,
#  137348,
#  137350,
#  137351,
#  137352,
#  137357,
#  137362,
#  137364,
#  137369,
#  137370,
#  137372,
#  137373,
#  231450,
#  231458,
#  231492,
#  231515,
#  231586,
#  231598,
#  231605,
#  231648,
#  231653,
#  231654,
#  231689,
#  231712,
#  231713,
#  231772,
#  231829,
#  231847,
#  231877,
#  231879,
#  231882,
#  231883,
#  231889,
#  231903,
#  214747,
#  214765,
#  214770,
#  214771,
#  214780,
#  214920,
#  214924,
#  214933,
#  214976,
#  215005,
#  215022,
#  215059,
#  215091,
#  157543,
#  157544,
#  157545,
#  157546,
#  157548,
#  157552,
#  157553,
#  157555,
#  157556,
#  157557,
#  157558,
#  157560,
#  157563,
#  157564,
#  157565,
#  157569,
#  157571,
#  157572,
#  157573,
#  157575,
#  157576,
#  157577,
#  157578,
#  157580,
#  157581,
#  157582,
#  157583,
#  157584,
#  157589,
#  157661,
#  157663,
#  157665,
#  157671,
#  157674,
#  157675,
#  157691,
#  157692,
#  157694,
#  157696,
#  157698,
#  157702,
#  157705,
#  157708,
#  157710,
#  157738,
#  157740,
#  157756,
#  157759,
#  157760,
#  157769,
#  157771,
#  157772,
#  157788,
#  157790,
#  157791,
#  157792,
#  157808,
#  157809,
#  157814,
#  157819,
#  157820,
#  157822,
#  157825,
#  157827,
#  157828,
#  157830,
#  157837,
#  157856,
#  157858,
#  157863,
#  157864,
#  157866,
#  157867,
#  157868,
#  157869,
#  157870,
#  157872,
#  157873,
#  157876,
#  157883,
#  157897,
#  157900,
#  157912,
#  157916,
#  157917,
#  157920,
#  157923,
#  157924,
#  157925,
#  157927,
#  157928,
#  157930,
#  157932,
#  157933,
#  157934,
#  157935,
#  157936,
#  157937,
#  157939,
#  157941,
#  157954,
#  157959,
#  157965,
#  157982,
#  157985,
#  157986,
#  157987,
#  157990,
#  157991,
#  158000,
#  158003,
#  158004,
#  158013,
#  158021,
#  158022,
#  158023,
#  158024,
#  158025,
#  158026,
#  158027,
#  158028,
#  158029,
#  158030,
#  158031,
#  158033,
#  158034,
#  158036,
#  158037,
#  158038,
#  158039,
#  158040,
#  158047,
#  158048,
#  158049,
#  158050,
#  158058,
#  158065,
#  158066,
#  158076,
#  107025,
#  107127,
#  107153,
#  107325,
#  282029,
#  282131,
#  282153,
#  282171,
#  282173,
#  282258,
#  282315,
#  282351,
#  26156,
#  26158,
#  26161,
#  26165,
#  26167,
#  26169,
#  26170,
#  26172,
#  26173,
#  26174,
#  26177,
#  26179,
#  26182,
#  26184,
#  26191,
#  26198,
#  26209,
#  26211,
#  26212,
#  26213,
#  26217,
#  26238,
#  26239,
#  26240,
#  26245,
#  26247,
#  26251,
#  26254,
#  26256,
#  26265,
#  26274,
#  26283,
#  26286,
#  26287,
#  26290,
#  26291,
#  26297,
#  26300,
#  26301,
#  26305,
#  26310,
#  26312,
#  26322,
#  26344,
#  26346,
#  26348,
#  26353,
#  26354,
#  26356,
#  26359,
#  26362,
#  26363,
#  26365,
#  26366,
#  26396,
#  26446,
#  26447,
#  26474,
#  26481,
#  26484,
#  26485,
#  26487,
#  26489,
#  26491,
#  26505,
#  26513,
#  26517,
#  26524,
#  26525,
#  26526,
#  26535,
#  26536,
#  26538,
#  26545,
#  26546,
#  26551,
#  26555,
#  26560,
#  26566,
#  26567,
#  26570,
#  26581,
#  26585,
#  26587,
#  26591,
#  26593,
#  26604,
#  26609,
#  26614,
#  26616,
#  26619,
#  26622,
#  26624,
#  26632,
#  26638,
#  26641,
#  26650,
#  26653,
#  26657,
#  26660,
#  26661,
#  26665,
#  26670,
#  354855,
#  355292,
#  355303,
#  87358,
#  87359,
#  87360,
#  87362,
#  87364,
#  87366,
#  87367,
#  87369,
#  87375,
#  87377,
#  87378,
#  87381,
#  87383,
#  87390,
#  87391,
#  87394,
#  87395,
#  87397,
#  87398,
#  87409,
#  87411,
#  87412,
#  87413,
#  87414,
#  87417,
#  87421,
#  87422,
#  87424,
#  87430,
#  87434,
#  87437,
#  87445,
#  87447,
#  87448,
#  87480,
#  87524,
#  87525,
#  87527,
#  87551,
#  87555,
#  87599,
#  87600,
#  87603,
#  87610,
#  87613,
#  87614,
#  87615,
#  87617,
#  87618,
#  87653,
#  87666,
#  87678,
#  87679,
#  87682,
#  87684,
#  87686,
#  87689,
#  87691,
#  87694,
#  87695,
#  87697,
#  87698,
#  87700,
#  87701,
#  87703,
#  87706,
#  87709,
#  87710,
#  87713,
#  498225,
#  498295,
#  498383,
#  498404,
#  498406,
#  283225,
#  283228,
#  283233,
#  283238,
#  283240,
#  283241,
#  283243,
#  283248,
#  283249,
#  283250,
#  283251,
#  283252,
#  283254,
#  283257,
#  283258,
#  283261,
#  283264,
#  283265,
#  283267,
#  283273,
#  283275,
#  283276,
#  283277,
#  283278,
#  283283,
#  283290,
#  283295,
#  283296,
#  283297,
#  283298,
#  283299,
#  283301,
#  283302,
#  283304,
#  283305,
#  283306,
#  283310,
#  283311,
#  283314,
#  283315,
#  283318,
#  283320,
#  283323,
#  283324,
#  283330,
#  283333,
#  283335,
#  283342,
#  283343,
#  283344,
#  283349,
#  283350,
#  283352,
#  283355,
#  283356,
#  283357,
#  283358,
#  283364,
#  283367,
#  283371,
#  283372,
#  283373,
#  283376,
#  283378,
#  283380,
#  283381,
#  283383,
#  283387,
#  283388,
#  283389,
#  283391,
#  283392,
#  283395,
#  283396,
#  283398,
#  283399,
#  283400,
#  283403,
#  283404,
#  283406,
#  283408,
#  283410,
#  283418,
#  283420,
#  283421,
#  283426,
#  283427,
#  283428,
#  283429,
#  283430,
#  283431,
#  283433,
#  283434,
#  283437,
#  283439,
#  283441,
#  283442,
#  283457,
#  283459,
#  283462,
#  283464,
#  283465,
#  283467,
#  283473,
#  283478,
#  283479,
#  283480,
#  283499,
#  283502,
#  283503,
#  283509,
#  283511,
#  283513,
#  283515,
#  283518,
#  283524,
#  283527,
#  283544,
#  283548,
#  283552,
#  283553,
#  283554,
#  283564,
#  283566,
#  283567,
#  283569,
#  283570,
#  283571,
#  283599,
#  283601,
#  283602,
#  283604,
#  283612,
#  283613,
#  283615,
#  283620,
#  283629,
#  283637,
#  283638,
#  283640,
#  283644,
#  283655,
#  283669,
#  283673,
#  283698,
#  283703,
#  283704,
#  283714,
#  283716,
#  278931,
#  279009,
#  279056,
#  279077,
#  279090,
#  279094,
#  279134,
#  279145,
#  279149,
#  279198,
#  279303,
#  279309,
#  279348,
#  279413,
#  279414,
#  279422,
#  279423,
#  279429,
#  68923,
#  68943,
#  68983,
#  69013,
#  69014,
#  69024,
#  69134,
#  69148,
#  69194,
#  69229,
#  69232,
#  69234,
#  69295,
#  69297,
#  69301,
#  69305,
#  69307,
#  69315,
#  69319,
#  69320,
#  69342,
#  69352,
#  69401,
#  69402,
#  27328,
#  27341,
#  27344,
#  27347,
#  27356,
#  27361,
#  27362,
#  27363,
#  27367,
#  27370,
#  27381,
#  27385,
#  27386,
#  27387,
#  27389,
#  27391,
#  27397,
#  27400,
#  27401,
#  27402,
#  27408,
#  27409,
#  27411,
#  27416,
#  27420,
#  27432,
#  27434,
#  27436,
#  27437,
#  27438,
#  27439,
#  27449,
#  27451,
#  27452,
#  27456,
#  27458,
#  27463,
#  27465,
#  27466,
#  27471,
#  27473,
#  27475,
#  27480,
#  27481,
#  27484,
#  27485,
#  27489,
#  27494,
#  27495,
#  27497,
#  27499,
#  27501,
#  27502,
#  27503,
#  27504,
#  27505,
#  27509,
#  27510,
#  27511,
#  27513,
#  27515,
#  27518,
#  27524,
#  27525,
#  27526,
#  27527,
#  27532,
#  27536,
#  27538,
#  27544,
#  27546,
#  27549,
#  27550,
#  27551,
#  27553,
#  27560,
#  27561,
#  27565,
#  27566,
#  27568,
#  27576,
#  27589,
#  27594,
#  27602,
#  27603,
#  27609,
#  27611,
#  27613,
#  27615,
#  27620,
#  27633,
#  27639,
#  27640,
#  27644,
#  27647,
#  27651,
#  27652,
#  27653,
#  27654,
#  27658,
#  27662,
#  27663,
#  27677,
#  27678,
#  27680,
#  27681,
#  27682,
#  27683,
#  27687,
#  27688,
#  27689,
#  27694,
#  27697,
#  27698,
#  27699,
#  27701,
#  27703,
#  27706,
#  27707,
#  27710,
#  27713,
#  27718,
#  27720,
#  27724,
#  27725,
#  27728,
#  27729,
#  27730,
#  27734,
#  27736,
#  27737,
#  27745,
#  27760,
#  27762,
#  309748,
#  309908,
#  309909,
#  309932,
#  309949,
#  309952,
#  309958,
#  309970,
#  309994,
#  310038,
#  310053,
#  310054,
#  310061,
#  310066,
#  310067,
#  310070,
#  310096,
#  310101,
#  310113,
#  338113,
#  338120,
#  338126,
#  338133,
#  338134,
#  338162,
#  338177,
#  338200,
#  338203,
#  338235,
#  338244,
#  338260,
#  338298,
#  338300,
#  338301,
#  338331,
#  338332,
#  338416,
#  338442,
#  338468,
#  338515,
#  338546,
#  338570,
#  284520,
#  284539,
#  284540,
#  284630,
#  284694,
#  284726,
#  284783,
#  284792,
#  284870,
#  284877,
#  284887,
#  284888,
#  284898,
#  284953,
#  284955,
#  284959,
#  284962,
#  284963,
#  284965,
#  284968,
#  284975,
#  284976,
#  284980,
#  284982,
#  284986,
#  284987,
#  284990,
#  284992,
#  284994,
#  20858,
#  20906,
#  20929,
#  20953,
#  20975,
#  20979,
#  20997,
#  21015,
#  21019,
#  21027,
#  21034,
#  21036,
#  21041,
#  21042,
#  21043,
#  21044,
#  21109,
#  21154,
#  21162,
#  21167,
#  21168,
#  21189,
#  21196,
#  21201,
#  21203,
#  21210,
#  21268,
#  21297,
#  21309,
#  21314,
#  21319,
#  21321,
#  21325,
#  499353,
#  499499,
#  499550,
#  499572,
#  499573,
#  499574,
#  499577,
#  499579,
#  499618,
#  499673,
#  499676,
#  499677,
#  499756,
#  499759,
#  499760,
#  499767,
#  499769,
#  499782,
#  499783,
#  499793,
#  499817,
#  499819,
#  499820,
#  499824,
#  499825,
#  499832,
#  499844,
#  240352,
#  240358,
#  240360,
#  240363,
#  240364,
#  240368,
#  240369,
#  240372,
#  240373,
#  240377,
#  240378,
#  240379,
#  240380,
#  240381,
#  240383,
#  240385,
#  240387,
#  240391,
#  240393,
#  240394,
#  240397,
#  240398,
#  240399,
#  240401,
#  240405,
#  240408,
#  240411,
#  ...]

# %%
len(list_drop_index)
# Out:
# 442136

# %%
df_drop_index=pd.DataFrame({'drop_index':list_drop_index})
df_drop_index.head()
# Out:
#    drop_index
# 0       75169
# 1       75181
# 2       75182
# 3       75184
# 4       75185

# %%
df_drop_index.to_csv('case1_drop_index.csv',index=False)

# %%
df_drop_index_case3=pd.DataFrame({'drop_index':null_list})
df_drop_index_case3.head()
# Out:
#    drop_index
# 0         225
# 1         253
# 2         277
# 3         510
# 4         517

# %%
df_drop_index_case3.to_csv('case3_drop_index.csv',index=False)

# %%
dup_index=pd.read_csv('dup_drop_index.csv',encoding='cp949')
case1=dup_index['drop_index'].values.tolist()

# %%
case2=list_drop_index
case3=null_list

# %%
final_drop_index=case1+case2+case3

# %%
len(final_drop_index)
# Out:
# 468637

# %%
df_review_.drop(final_drop_index,inplace=True)

# %%
df_review_.head()
# Out:
#                id  rate                                             review  \
# 0    화늠(nhh5****)     5                            댓글 알바가 판을 치는군요 보면 압니다..
# 1     님(3328****)     2                    휴~ 90년대 개그와 cg…긴장감 전혀 없는 재난영화??
# 2  오이건축(jeon****)     2  두서도 없고,맥락도 없고,감동도 없고,유머만 조금,우주전쟁영화도 개연성이 있는데, ...
# 3    비즈(inab****)     5                                       기대보다 별로였어요..
# 4        xovk****     8                         승원이형 오랜만에 무도 한 편 더 찍으셨네요^^
#
#   title
# 0   싱크홀
# 1   싱크홀
# 2   싱크홀
# 3   싱크홀
# 4   싱크홀

# %%
drop_id=pd.read_csv('case2_drop_name_list.csv',encoding='cp949')
drop_id_list=drop_id['name'].values.tolist()

# %%
df_final=None
for i in range(len(drop_id_list)):
    tf=df_review_[df_review_['id']==drop_id_list[i]]
    df_final=pd.concat([df_final,tf])

# %%
dup_id_index=df_final.index.tolist()

# %%
df_review_.drop(dup_id_index,inplace=True)

# %%
df_review_.to_csv('final.csv',index=False)

# %% [markdown]
# ### 가짜리뷰 제거 후(리뷰 보정후) 영화별 리뷰

# %%
df_review_.groupby(['title'])['rate'].mean()
# Out:
# title
# 007 노 타임 투 다이    6.334086
# 가을의 전설           8.698851
# 강릉               6.387179
# 경관의 피            7.211207
# 고스트버스터즈 라이즈      7.632258
#                    ...
# 해피 뉴 이어          6.182033
# 헤어질 결심           9.501035
# 호빗 : 뜻밖의 여정      9.344754
# 호빗 : 스마우그의 폐허    9.477223
# 호빗: 다섯 군대 전투     9.243534
# Name: rate, Length: 80, dtype: float64

# %%
review_real=df_review.groupby(['title'])['rate'].mean().values.tolist()

# %%
df_review_final=df_review_.groupby(['title'])['rate'].mean().reset_index()

# %%
df_review_final['real_review']=review_real

# %%
df_review_final.rename(columns={'title':'title','rate':'corrected_rate','real_review':'real_rate'},inplace=True)

# %%
df_review_final.to_csv('rate_correction.csv',index=False)

# %%
df_review_final['corrected_rate']-df_review_final['real_rate']
# Out:
# 0    -0.328475
# 1     0.030479
# 2     1.176215
# 3     0.045860
# 4     0.013650
#         ...
# 75   -0.759988
# 76    0.898162
# 77    0.885554
# 78    0.915799
# 79    0.703463
# Length: 80, dtype: float64
